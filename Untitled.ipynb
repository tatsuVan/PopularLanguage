# %%
import numpy as np
import matplotlib.pyplot as plt
python =10
javascript = 20
php = 30
ruby = 40
c = 50
java=60
labels = ['python', 'javascript', 'php', 'ruby', 'c', 'java']
x = np.array([10,20,30,40,50,60])
print(x)
x = np.sort(x)[::-1]
print(x)


# xx = np.array(["python":python])
plt.figure()
plt.pie(x, labels=labels, counterclock=False, startangle=90, autopct="%.1f%%", pctdistance=0.7, textprops={'fontsize': 18}, radius=2)
plt.rcParams["font.size"] = 18
plt.axis('equal')
# dirname = "static/"
# filename = dirname + country+".jpg"
# plt.savefig(filename)
# row = Data(date=datetime.datetime.today(), country=country, python=_results["python"], javascript=_results["javascript"], php=_results["php"], ruby=_results["ruby"], c=_results["c"], java=_results["java"])
# db_session.add(row)
# Out:
# [10 20 30 40 50 60]
# [60 50 40 30 20 10]
# (-2.2183832742296756,
#  2.2183832671081705,
#  -2.2554808029934876,
#  2.202641960126732)

# %%
import numpy as np
import matplotlib.pyplot as plt
python =10
javascript = 20
php = 30
ruby = 2000
c = 50
java=60
labels = ['python', 'javascript', 'php', 'ruby', 'c', 'java']
x = {'python':python, 'javascript':javascript, 'php': php,'ruby': ruby, 'c': c, 'java':java}
print(x)
x_sorted = sorted(x.items(), key=lambda x:x[1], reverse=True)
# xx =np.array(['python',python],['javascript':javascript])
# xx = np.sort(x)[::-1]
# x = [10,20,30,40,50,60]
print(x_sorted)
labels = []
y = []
for name, number in x_sorted:
    labels.append(name)
    y.append(number)
#     y.appned(sorted_dict[0])
print(labels)
print(y)
#
# Out:
# {'python': 10, 'javascript': 20, 'php': 30, 'ruby': 2000, 'c': 50, 'java': 60}
# [('ruby', 2000), ('java', 60), ('c', 50), ('php', 30), ('javascript', 20), ('python', 10)]
# ['ruby', 'java', 'c', 'php', 'javascript', 'python']
# [2000, 60, 50, 30, 20, 10]

# %%
from flask import Flask, render_template
from assets.database import db_session
from assets.models import Data

# %%
data = db_session.query(Data).all()[-1]
db_session.delete(data)
# Out:
# 2021-04-04 21:05:05,936 INFO sqlalchemy.engine.base.Engine SELECT data.id AS data_id, data.date AS data_date, data.country AS data_country, data.python AS data_python, data.javascript AS data_javascript, data.php AS data_php, data.ruby AS data_ruby, data.c AS data_c, data.java AS data_java, data.timestamp AS data_timestamp
# FROM data
# 2021-04-04 21:05:05,937 INFO sqlalchemy.engine.base.Engine ()

# %%
db_session.commit
